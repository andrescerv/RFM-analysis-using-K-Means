# %%
import pandas as pd
import seaborn as sns
from sqlalchemy import create_engine

user = 'andres'
password = '4&-GBGeRgAJWfJ_N'
localhost = '52.9.101.52'
database = 'mkt_sandbox'

db_url = f'mysql+pymysql://{user}:{password}@{localhost}/{database}'

engine = create_engine(db_url)
engine

# %%
q = """
select *
from 00_sandbox.user_catalogues
order by rand()
limit 100000
"""

# %%
# df = pd.read_sql(q, engine)

# %%
df.set_index('user_id', drop=True, inplace=True)

# %%
df.head()
# Out:
#          session_id  wallet_id facebook_id      user_name      mobile address  \
# user_id
# 3995875         0.0  3974913.0           0        Jonatan  2147483647    None
# 228828          0.0   208767.0           0                          0    None
# 4197870         NaN  4176841.0  2147483647         Are HV        None    None
# 2570770         0.0  2550438.0  2147483647  Chikis Montez           0    None
# 2522092         0.0  2501772.0           0       Anakaren  2147483647    None
#
#                                       email  age gender nivel_soceco  ...  \
# user_id                                                               ...
# 3995875  jonathanrodriguezmedina6@gmail.com  NaN   None         None  ...
# 228828         cesar150gamer150@outlook.com  NaN   None         None  ...
# 4197870        221179133348246@facebook.com  NaN   None         None  ...
# 2570770       2468643416788639@facebook.com  NaN   None         None  ...
# ...

# %%
df.columns # these are the 85 columns in the original dataset
# Out:
# Index(['session_id', 'wallet_id', 'facebook_id', 'user_name', 'mobile',
#        'address', 'email', 'age', 'gender', 'nivel_soceco', 'trust_score',
#        'reg_date', 'first_txn_date', 'days_bef_first_txn', 'cohort_year',
#        'cohort_ym', 'cohort_yq', 'cohort_dayname', 'cohort_delivery',
#        'cohort_channel', 'cohort_campaign', 'cohort_device', 'cohort_cat1',
#        'cohort_cat2', 'cohort_sku', 'cohort_supplier', 'cohort_app_version',
#        'count_sessions', 'count_clicks_24h', 'count_paynow', 'num_tarjetas',
#        'bins_attempted', 'num_nombres_en_tarjeta', 'count_txns_attempted',
#        'count_blacklist', 'count_velocity', 'count_chargebacks',
#        'count_payment_error', 'count_fulfillment_error',
#        'count_categories_attempted', 'count_sku_attempt', 'count_net_txns',
#        'count_net_categories', 'count_net_sku', 'first_txn_gtv',
#        'first_txn_bracket_gtv', 'first_txn_pc1', 'first_txn_pc2',
# ...

# %%
cols = [
    'trust_score',
    'count_net_txns',
    'sum_gtv',
    'sum_pc1',
    'sum_pc2',
    'sum_pc3'
] # filtering only relevant columns

# %%
df2 = df[cols]
df2
# Out:
#          trust_score  count_net_txns  sum_gtv  sum_pc1  sum_pc2  sum_pc3
# user_id
# 3995875     9.735710             4.0    110.0     9.38     6.43     6.43
# 228828    -16.700001             1.0    100.0     7.83    -6.67    -6.67
# 4197870    10.314285             2.0    443.5    50.50    36.50    36.50
# 2570770     9.750000             3.0    100.0    10.00     7.80     7.80
# 2522092     0.628570             1.0     50.0     5.00     4.00     4.00
# ...              ...             ...      ...      ...      ...      ...
# 2004558   -16.837139             1.0    200.0    14.30    10.00    10.00
# 1032014   126.069458            68.0    960.0   102.57    25.15    25.15
# 1514487    27.200001             4.0     40.0     4.36     3.52     3.52
# 2865062    55.807140             8.0    330.0    30.50    18.26    18.26
# 2097363     3.600000             1.0     20.0     1.43     1.43     1.43
#
# [100000 rows x 6 columns]

# %%
df2.describe()
# Out:
#         trust_score  count_net_txns       sum_gtv       sum_pc1       sum_pc2  \
# count  99999.000000    99979.000000  9.997900e+04  99979.000000  99979.000000
# mean    -958.376046       13.030997  9.469812e+02     68.733446     37.292269
# std     7145.211292       52.490652  5.778799e+03    374.548783    279.144680
# min   -99409.117188        0.000000  0.000000e+00   -503.360000  -4107.489700
# 25%        3.152860        1.000000  5.000000e+01      3.830000      1.540000
# 50%       20.000000        2.000000  1.200000e+02     10.870000      5.100000
# 75%       40.563395        6.000000  4.349700e+02     38.320000     19.500000
# max     1016.128540     7810.000000  1.232154e+06  90284.101600  75138.859400
#
#             sum_pc3
# count  99979.000000
# mean      17.328898
# std      345.229824
# min   -20871.500000
# 25%        1.170000
# 50%        4.600000
# 75%       17.330000
# max    74038.859400

# %%
df2.shape
# Out:
# (100000, 6)

# %% [markdown]
# # Handling outliers

# %%
df2['trust_score'].quantile(0.9) # 158
# df2['trust_score'].quantile(0.05) # -25,003
# df2['count_net_txns'].quantile(0.95) # 180
# df2['sum_gtv'].quantile(0.95) # 13,591
# df2['sum_pc1'].quantile(0.95) # 936
# df2['sum_pc2'].quantile(0.95) # 555
# df2['sum_pc3'].quantile(0.25) # 540
# Out:
# 94.50938110351562

# %%
df3 = df2[df2['trust_score'] <= df2['trust_score'].quantile(0.9)]
df3 = df3[df3['trust_score'] >= df2['trust_score'].quantile(0.1)]

df3 = df3[df3['count_net_txns'] <= df2['count_net_txns'].quantile(0.9)]
# df3 = df3[df3['count_net_txns'] >= df2['count_net_txns'].quantile(0.1)]

df3 = df3[df3['sum_gtv'] <= df2['sum_gtv'].quantile(0.9)]
# df3 = df3[df3['sum_pc1'] >= df2['sum_gtv'].quantile(0.1)]

df3 = df3[df3['sum_pc2'] <= df2['sum_pc1'].quantile(0.9)]
# df3 = df3[df3['sum_pc3'] >= df2['sum_pc1'].quantile(0.1)]

df3 = df3[df3['sum_gtv'] <= df2['sum_pc2'].quantile(0.9)]
# df3 = df3[df3['sum_pc1'] >= df2['sum_pc2'].quantile(0.1)]

df3 = df3[df3['sum_pc2'] <= df2['sum_pc3'].quantile(0.9)]
# df3 = df3[df3['sum_pc3'] >= df2['sum_pc3'].quantile(0.1)]

# %%
df3.describe()
# Out:
#         trust_score  count_net_txns       sum_gtv      sum_pc1       sum_pc2  \
# count  35087.000000    35087.000000  35087.000000  35087.00000  35087.000000
# mean      15.554170        1.404395     34.115418      3.35247      1.629119
# std       14.424179        0.940622     20.383281      4.59185      4.886434
# min      -18.600000        0.000000      0.000000   -343.57000   -361.850000
# 25%        4.439330        1.000000     20.000000      1.50000      0.720000
# 50%       16.200001        1.000000     30.000000      2.86000      1.600000
# 75%       25.400000        2.000000     50.000000      4.00000      2.730000
# max       94.207138        8.000000     84.380000    189.58000     76.500000
#
#             sum_pc3
# count  35087.000000
# mean       1.553592
# std        5.693273
# min     -361.850000
# 25%        0.720000
# 50%        1.600000
# 75%        2.730000
# max       76.500000

# %%
df3.shape
# Out:
# (35087, 6)

# %% [markdown]
# # Visualization

# %%
ax = sns.pairplot(data=df3, kind="reg", diag_kind='kde', plot_kws={'line_kws':{'color':'red'}})

# %%
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
x = df2[numeric_cols].values
x_scaled = min_max_scaler.fit_transform(x)
df_scaled = pd.DataFrame(x_scaled, columns=numeric_cols)
df_scaled = pd.concat([df2['user_id'],df_scaled], axis=1)
df_scaled
# Out:
#     user_id  trust_score  count_net_txns   sum_gtv   sum_pc1   sum_pc2  \
# 0         1          NaN        0.031955  0.002425  0.017062  0.322672
# 1        62     0.816333        0.009398  0.000593  0.009289  0.609145
# 2        63     0.819098        0.009398  0.001161  0.010518  0.610169
# 3        65     0.820236        0.031955  0.002941  0.019372  0.617943
# 4        66     0.809127        0.000000  0.000206  0.007133  0.607689
# ..      ...          ...             ...       ...       ...       ...
# 95    23418     0.834558        0.097744  0.009233  0.000000  0.579174
# 96    23420     0.813329        0.001880  0.000354  0.007611  0.608024
# 97    23421     0.809498        0.000000  0.000206  0.007133  0.607425
# 98    23422     0.817906        0.005639  0.000666  0.010596  0.612320
# 99    23423     0.842156        0.351504  0.058826  0.255487  0.734047
#
#      sum_pc3
# 0   0.253197
# 1   0.609145
# 2   0.610169
# 3   0.617943
# 4   0.607689
# ..       ...
# ...

# %%
df_scaled.dropna(inplace=True)

# %% [markdown]
# # Visualization

# %%
# hierarchical clustering will help us visualize the clusters
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import fcluster, linkage, dendrogram

distance_matrix = linkage(df_scaled, method='ward', metric='euclidean')

df_scaled['label_hc'] = fcluster(distance_matrix, 3, criterion='maxclust')

dn = dendrogram(distance_matrix, truncate_mode='lastp')

plt.title("Dendrogram shows 2 clusters in the 'longest height difference' between nodes.")
plt.xlabel('observations (users)')
plt.ylabel('height')

plt.show() # There are 2 clusters or segments.

# %%
df_scaled.label_hc.unique()
# Out:
# array([1, 2, 3], dtype=int32)

# %% [markdown]
# # k-means

# %%
from scipy.cluster.vq import kmeans, vq

df_km = df_scaled.drop(columns=['label_hc']) # removing label so the algorithm isn't affected

cluster_centers, _ = kmeans(df_km, 3) # we select 3 clusters
df_km['label_km'], _ = vq(df_km, cluster_centers) # labels created

df_scaled['label_km'] = df_km['label_km'] # adding labels to df_scaled for comparison

# %%
df_scaled
# Out:
#     user_id  trust_score  count_net_txns   sum_gtv   sum_pc1   sum_pc2  \
# 1        62     0.816333        0.009398  0.000593  0.009289  0.609145
# 2        63     0.819098        0.009398  0.001161  0.010518  0.610169
# 3        65     0.820236        0.031955  0.002941  0.019372  0.617943
# 4        66     0.809127        0.000000  0.000206  0.007133  0.607689
# 5        78     0.810339        0.000000  0.000000  0.006212  0.606883
# ..      ...          ...             ...       ...       ...       ...
# 95    23418     0.834558        0.097744  0.009233  0.000000  0.579174
# 96    23420     0.813329        0.001880  0.000354  0.007611  0.608024
# 97    23421     0.809498        0.000000  0.000206  0.007133  0.607425
# 98    23422     0.817906        0.005639  0.000666  0.010596  0.612320
# 99    23423     0.842156        0.351504  0.058826  0.255487  0.734047
#
#      sum_pc3  label_hc  label_km
# 1   0.609145         1         0
# 2   0.610169         1         0
# ...

# %%
df_scaled.groupby(['label_hc','label_km']).count().iloc[:,0]
# Out:
# label_hc  label_km
# 1         0           12
# 2         1           10
# 3         2           67
# Name: user_id, dtype: int64

# %%
df_scaled[df_scaled['label_km'] == 0]
# Out:
#     user_id  trust_score  count_net_txns   sum_gtv   sum_pc1   sum_pc2  \
# 1        62     0.816333        0.009398  0.000593  0.009289  0.609145
# 2        63     0.819098        0.009398  0.001161  0.010518  0.610169
# 3        65     0.820236        0.031955  0.002941  0.019372  0.617943
# 4        66     0.809127        0.000000  0.000206  0.007133  0.607689
# 5        78     0.810339        0.000000  0.000000  0.006212  0.606883
# 6        83     0.989174        0.031955  0.005150  0.062470  0.678944
# 7        86     0.837566        0.031955  0.002941  0.021224  0.616280
# 8       102     0.830351        0.073308  0.016486  0.060831  0.645249
# 9       111     0.808644        0.000000  0.000000  0.006209  0.606971
# 10      114     0.809610        0.001880  0.000464  0.008133  0.608522
# 11      122     0.000000        0.000000  0.000206  0.007183  0.605009
# 12      124     0.007677        0.001880  0.000026  0.006327  0.606285
#
#      sum_pc3  label_hc  label_km
# ...

# %%
df_scaled[df_scaled['label_km'] == 1]
# Out:
#     user_id  trust_score  count_net_txns   sum_gtv   sum_pc1   sum_pc2  \
# 23    23216     0.809304        0.000000  0.000206  0.007183  0.607765
# 24    23219     0.816335        0.001880  0.000851  0.010019  0.608522
# 25    23223     0.815468        0.007519  0.001677  0.013606  0.614826
# 26    23225     0.829973        0.062030  0.008978  0.053129  0.647248
# 27    23255     0.815989        0.000000  0.000335  0.008489  0.609474
# 28    23258     0.813396        0.000000  0.000077  0.006529  0.607202
# 29    23262     0.816730        0.001880  0.000052  0.006631  0.606996
# 30    23267     0.810142        0.003759  0.000542  0.008634  0.609632
# 31    23268     0.814137        0.001880  0.000103  0.006686  0.607387
# 32    23279     0.811575        0.000000  0.000335  0.008489  0.609474
#
#      sum_pc3  label_hc  label_km
# 23  0.607765         2         1
# 24  0.608522         2         1
# 25  0.614826         2         1
# 26  0.647248         2         1
# ...

# %%
df_scaled[df_scaled['label_km'] == 2]
# Out:
#     user_id  trust_score  count_net_txns   sum_gtv   sum_pc1   sum_pc2  \
# 33    23328     0.813041        0.000000  0.000026  0.006324  0.606829
# 34    23337     0.810297        0.022556  0.003509  0.019449  0.617718
# 35    23339     0.872923        0.996241  1.000000  0.399005  0.000000
# 36    23341     0.015404        0.016917  0.004463  0.013679  0.600954
# 37    23342     0.842004        0.518797  0.692586  0.459490  0.423378
# ..      ...          ...             ...       ...       ...       ...
# 95    23418     0.834558        0.097744  0.009233  0.000000  0.579174
# 96    23420     0.813329        0.001880  0.000354  0.007611  0.608024
# 97    23421     0.809498        0.000000  0.000206  0.007133  0.607425
# 98    23422     0.817906        0.005639  0.000666  0.010596  0.612320
# 99    23423     0.842156        0.351504  0.058826  0.255487  0.734047
#
#      sum_pc3  label_hc  label_km
# 33  0.606829         3         2
# 34  0.617718         3         2
# ...

# %%
df_scaled.groupby('label_km').agg({"trust_score":"mean"})
# Out:
#           trust_score
# label_km
# 0            0.696513
# 1            0.815305
# 2            0.805479

# %%
df_scaled.groupby('label_km').agg({"count_net_txns":"mean"})
# Out:
#           count_net_txns
# label_km
# 0               0.015977
# 1               0.007895
# 2               0.155145

# %%
df_scaled.groupby('label_km').agg({"sum_gtv":"mean"})
# Out:
#            sum_gtv
# label_km
# 0         0.002515
# 1         0.001316
# 2         0.053035

# %%
df_scaled.groupby('label_km').agg({"sum_pc1":"mean"})
# Out:
#            sum_pc1
# label_km
# 0         0.018742
# 1         0.012939
# 2         0.104090

# %%
df_scaled.groupby('label_km').agg({"sum_pc2":"mean"})
# Out:
#            sum_pc2
# label_km
# 0         0.618257
# 1         0.612853
# 2         0.641313

# %%
df_scaled.groupby('label_km').agg({"sum_pc3":"mean"})
# Out:
#            sum_pc3
# label_km
# 0         0.616328
# 1         0.612853
# 2         0.637615

# %% [markdown]
# # RFM analysis
#
# https://towardsdatascience.com/customer-segmentation-in-python-9c15acf6f945

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine

# %%
user = 'andres'
password = '4&-GBGeRgAJWfJ_N'
localhost = '52.9.101.52'
database = 'mkt_sandbox'

db_url = f'mysql+pymysql://{user}:{password}@{localhost}/{database}'

engine = create_engine(db_url)
engine
# Out:
# Engine(mysql+pymysql://andres:***@52.9.101.52/mkt_sandbox)

# %%
# q = """
# select
#     user_id,
#     created_at,
#     gtv
# from matrix.net_txns
# where yearmonth >= extract(year_month from date_sub(now(),interval 6 month))
# """

q = """
select *
from mkt_sandbox.acn_rfm
"""

# %%
df = pd.read_sql(q, engine, index_col='user_id')

# %%
df.head()
# Out:
#                  created_at    gtv
# user_id
# 111728  2021-07-15 09:46:13  100.0
# 111728  2021-05-06 16:20:47   60.0
# 3876000 2021-03-07 20:32:19  226.5
# 3876000 2021-05-07 19:51:08  502.5
# 2843137 2021-04-06 09:48:44  373.5

# %%
df.shape
# Out:
# (5637706, 2)

# %%
df['created_at'].min()
# Out:
# Timestamp('2021-03-01 00:00:14')

# %%
df['created_at'].max()
# Out:
# Timestamp('2021-09-28 23:59:56')

# %% [markdown]
# ## Recency
# To get the number of days for recency column, we can subtract the snapshot date with the date where the transaction occurred.

# %%
from datetime import datetime

recency_df = df.groupby(df.index).agg({'created_at':'max'})
recency_df['now'] = pd.to_datetime(datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
recency_df['recency'] = (recency_df['now'] - recency_df['created_at']).dt.days
recency_df.drop(columns=['created_at','now'], inplace=True)
recency_df = recency_df + 1
recency_df
# Out:
#          recency
# user_id
# 62           155
# 102           28
# 23225        124
# 23261         45
# 23339          3
# ...          ...
# 4254399        2
# 4254403        2
# 4254404        2
# 4254405        2
# 4254408        2
#
# [398497 rows x 1 columns]

# %% [markdown]
# ## Frequency
# To create the frequency column, we can count how much transactions by each customer.

# %%
freq_df = df.index.value_counts().to_frame('frequency')
freq_df.index.name = 'user_id'
freq_df
# Out:
#          frequency
# user_id
# 1395001       7138
# 568390        3613
# 297175        3341
# 1261997       3051
# 111728        2872
# ...            ...
# 2432299          1
# 2735295          1
# 1452877          1
# 4239774          1
# 4200445          1
#
# [398497 rows x 1 columns]

# %% [markdown]
# ## Monetary Value
# Lastly, to create the monetary value column, we can sum all transactions for each customer.

# %%
mval_df = df.groupby([df.index]).agg({'gtv': 'sum'}).rename(columns={"gtv":"monetary_value"})
mval_df
# Out:
#          monetary_value
# user_id
# 62                 50.0
# 102              2950.0
# 23225             200.0
# 23261              10.0
# 23339          226510.6
# ...                 ...
# 4254399           200.0
# 4254403           109.0
# 4254404            30.0
# 4254405            50.0
# 4254408           200.0
#
# [398497 rows x 1 columns]

# %% [markdown]
# ## concat

# %%
rfm_df = pd.concat([recency_df, freq_df, mval_df], axis=1)
rfm_df.head()
# Out:
#          recency  frequency  monetary_value
# user_id
# 62           155          1            50.0
# 102           28         19          2950.0
# 23225        124          2           200.0
# 23261         45          1            10.0
# 23339          3         75        226510.6

# %%
# sns.histplot(data=rfm_df, x="recency", kde=True, discrete=True)

# %%
# sns.histplot(data=rfm_df, x="frequency")

# %%
# sns.histplot(data=rfm_df, x="monetary_value")

# %%
# sns.boxplot(data=rfm_df, x="monetary_value")

# %%
rfm_df.describe()
# Out:
#              recency      frequency  monetary_value
# count  398497.000000  398497.000000    3.984970e+05
# mean       64.480950      14.147424    1.194501e+03
# std        63.669411      37.907450    1.330861e+04
# min         2.000000       1.000000    3.300000e-01
# 25%        10.000000       1.000000    1.000000e+02
# 50%        38.000000       4.000000    3.000000e+02
# 75%       111.000000      15.000000    1.060000e+03
# max       214.000000    7138.000000    7.958835e+06

# %% [markdown]
# ## Transformations

# %%
rfm_df.agg(['skew', 'kurtosis']).transpose()
# Out:
#                       skew       kurtosis
# recency           0.850118      -0.602986
# frequency        37.674072    4205.978074
# monetary_value  537.946091  320816.895564

# %% [markdown]
# ### square root transformation
# The square root method is typically used when your data is moderately skewed. Now using the square root (e.g., sqrt(x)) is  a transformation that has a moderate effect on distribution shape. It is generally used to reduce right skewed data. Finally, the square root can be applied on zero values and is most commonly used on counted data.

# %%
sqrt_df = np.sqrt(rfm_df)
trans1_df = sqrt_df.agg(['skew', 'kurtosis']).transpose()
trans1_df['transformation'] = 'Square Root'
trans1_df
# Out:
#                     skew    kurtosis transformation
# recency         0.341889   -1.230847    Square Root
# frequency       2.864863   22.949918    Square Root
# monetary_value  7.355822  477.117521    Square Root

# %% [markdown]
# ### log transformation
#
# The logarithmic is a strong transformation that has a major effect on distribution shape. This technique is, as the square root method, oftenly used for reducing right skewness. Worth noting, however, is that it can not be applied to zero or negative values.

# %%
log_df = np.log(rfm_df)
trans2_df = log_df.agg(['skew', 'kurtosis']).transpose()
trans2_df['transformation'] = 'Log'
trans2_df
# Out:
#                     skew  kurtosis transformation
# recency        -0.352019 -1.111400            Log
# frequency       0.409253 -0.832326            Log
# monetary_value  0.084821 -0.542242            Log

# %% [markdown]
# ### box-cox transformation
# The Box-Cox transformation is, as you probably understand, also a technique to transform non-normal data into normal shape. This is a procedure to identify a suitable exponent (Lambda = l) to use to transform skewed data.

# %%
from scipy.stats import boxcox

bcox_df = pd.DataFrame()

for ii, col in enumerate(rfm_df.columns):
    bcox_df[col] = boxcox(rfm_df.iloc[:,ii])[0]
    
trans3_df = bcox_df.agg(['skew', 'kurtosis']).transpose()
trans3_df['transformation'] = 'Box-Cox'
trans3_df
# Out:
#                     skew  kurtosis transformation
# recency        -0.099507 -1.284006        Box-Cox
# frequency       0.100211 -1.269106        Box-Cox
# monetary_value  0.006986 -0.586382        Box-Cox

# %% [markdown]
# ## comparing transformations

# %%
trans_df = pd.concat([trans1_df,trans2_df,trans3_df])
trans_df
# Out:
#                     skew    kurtosis transformation
# recency         0.341889   -1.230847    Square Root
# frequency       2.864863   22.949918    Square Root
# monetary_value  7.355822  477.117521    Square Root
# recency        -0.352019   -1.111400            Log
# frequency       0.409253   -0.832326            Log
# monetary_value  0.084821   -0.542242            Log
# recency        -0.099507   -1.284006        Box-Cox
# frequency       0.100211   -1.269106        Box-Cox
# monetary_value  0.006986   -0.586382        Box-Cox

# %%
np.sqrt(trans_df[['skew','kurtosis']] ** 2) # box-cox is the winner
# Out:
#                     skew    kurtosis
# recency         0.341889    1.230847
# frequency       2.864863   22.949918
# monetary_value  7.355822  477.117521
# recency         0.352019    1.111400
# frequency       0.409253    0.832326
# monetary_value  0.084821    0.542242
# recency         0.099507    1.284006
# frequency       0.100211    1.269106
# monetary_value  0.006986    0.586382

# %% [markdown]
# ### visualizing Box-Cox transformation

# %%
sns.histplot(data=bcox_df, x=bcox_df.iloc[:,0])
# Out:
# <AxesSubplot:xlabel='recency', ylabel='Count'>

# %%
sns.histplot(data=bcox_df, x=bcox_df.iloc[:,1])
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='Count'>

# %%
sns.histplot(data=bcox_df, x=bcox_df.iloc[:,2])
# Out:
# <AxesSubplot:xlabel='monetary_value', ylabel='Count'>

# %% [markdown]
# ## Normalization

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(bcox_df)
normal_df = scaler.transform(bcox_df)

print(normal_df.mean(axis = 0).round(2)) # [0. -0. 0.]
print(normal_df.std(axis = 0).round(2)) # [1. 1. 1.]
# Out:
# [0. 0. 0.]
# [1. 1. 1.]

# %%
normal_df
# Out:
# array([[ 1.23596935, -1.26259522, -1.07715812],
#        [-0.19352024,  0.98689153,  1.34770906],
#        [ 1.02583164, -0.62598325, -0.22866298],
#        ...,
#        [-1.73878897, -1.26259522, -1.39627842],
#        [-1.73878897, -1.26259522, -1.07715812],
#        [-1.73878897, -1.26259522, -0.22866298]])

# %% [markdown]
# ## Modelling

# %%
from sklearn.cluster import KMeans

sse = {}

for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(normal_df)
    sse[k] = kmeans.inertia_ # SSE to closest cluster centroid
    
plt.title('The Elbow Method')
plt.xlabel('k')
plt.ylabel('SSE')
sns.pointplot(x=list(sse.keys()), y=list(sse.values()))
plt.show()

# %%
model = KMeans(n_clusters=2)
model.fit(normal_df)
model.labels_.shape
# Out:
# (398497,)

# %%
rfm_df["cluster"] = model.labels_

rfm_df.groupby('cluster').agg({
    'recency':'mean',
    'frequency':'mean',
    'monetary_value':['mean', 'count']
}).round(2)
# Out:
#         recency frequency monetary_value
#            mean      mean           mean   count
# cluster
# 0         22.83     27.44        2349.19  188285
# 1        101.79      2.24         160.26  210212

# %%
# Create the dataframe
df_normalized = pd.DataFrame(normal_df, columns=['recency', 'frequency', 'monetary_value'])
df_normalized['user_id'] = rfm_df.index
df_normalized['cluster'] = model.labels_
df_normalized.head()
# Out:
#     recency  frequency  monetary_value  user_id  cluster
# 0  1.235969  -1.262595       -1.077158       62        1
# 1 -0.193520   0.986892        1.347709      102        0
# 2  1.025832  -0.625983       -0.228663    23225        1
# 3  0.163173  -1.262595       -2.094649    23261        1
# 4 -1.542956   1.703548        3.704901    23339        0

# %%
# Melt The Data
df_nor_melt = pd.melt(df_normalized.reset_index(),
                      id_vars=['user_id', 'cluster'],
                      value_vars=['recency','frequency','monetary_value'],
                      var_name='Attribute',
                      value_name='Value')
df_nor_melt.head()

# Visualize it
ax = sns.lineplot(x='Attribute', y='Value', hue='cluster', data=df_nor_melt)
plt.savefig('clusters.png')

# %% [markdown]
# ## Conclusion

# %% [markdown]
# * We infer that the customers in cluster 0 are recent buyers, don't buy frequently, and tend to spend less. Therefore, it could be the cluster of **new customer**.
# * We infer that the customers in cluster 1 are old buyers, buy frequently, and tend to spend more. Therefore, it could be the cluster of a **loyal customer**.

# %%
df = df_normalized
df.set_index('user_id', drop=True, inplace=True)

# %%
df.head()
# Out:
#           recency  frequency  monetary_value  cluster
# user_id
# 62       1.235969  -1.262595       -1.077158        1
# 102     -0.193520   0.986892        1.347709        0
# 23225    1.025832  -0.625983       -0.228663        1
# 23261    0.163173  -1.262595       -2.094649        1
# 23339   -1.542956   1.703548        3.704901        0
